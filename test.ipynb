# %%
from complete_method import CompleteMethod
import numpy as np
import pandas as pd
import os

vis = CompleteMethod(pd.read_csv('data_quy.csv'), "Data_CT", 63)
# Out:
# Cảnh báo: Các cột không được coi là biến để sinh công thức: ['TIME', 'PROFIT', 'SYMBOL', 'EXCHANGE']. Nếu danh sách trên có một cột cần được coi là biến, hãy kiểm tra lại kiểu dữ liệu của cột.
#
# Một dấu "/" đã được tự động thêm vào đường dẫn tới thư mục lưu công thức. Đường dẫn mới là: Data_CT/.

# %%
vis.generate_formula(-1.0, 200000, 1000000)
# Out:
# Khi ngắt bằng tay thì cần tự chạy phương thức <CompleteMethod_object>.save_history() để lưu lịch sử.
# Đang chạy sinh công thức có số toán hạng là  1 . . .
# Đã lưu lịch sử.
# Đã lưu công thức
# Đang chạy sinh công thức có số toán hạng là  2 . . .
# Đã lưu lịch sử.
# Đã lưu công thức
# Đang chạy sinh công thức có số toán hạng là  3 . . .
# Đã lưu lịch sử.
# Đã lưu công thức
# Đang chạy sinh công thức có số toán hạng là  4 . . .
# Đã lưu lịch sử.
# Đã lưu công thức
# Đã lưu lịch sử.
# Đã lưu công thức
# Đã lưu lịch sử.
# Đã lưu công thức
# Đã lưu lịch sử.
# Đã lưu công thức
# Đã lưu lịch sử.
# Đã lưu công thức
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 vis.generate_formula(-1.0, 200000, 1000000)
#
# ...

# %%
vis.convert_npy_file_to_DataFrame('Data_CT\high_profit_4_04_12_2022_18_39_54.npy')
# Out:
#            formula  geomean profit invest  profit
# 0       +25/3/13+0        1.028561    VIC     0.0
# 1       +25/3/13+1        0.963582    DLG     0.0
# 2       +25/3/13+2        0.949814    DLG     0.0
# 3       +25/3/13+3        1.022166    VIC     0.0
# 4       +25/3/13+4        0.971008    DLG     0.0
# ...            ...             ...    ...     ...
# 28629  +2*21+10*21        0.983757    VIC     0.0
# 28630  +2*21+10*22        0.983757    VIC     0.0
# 28631  +2*21+10*23        0.983757    VIC     0.0
# 28632  +2*21+10*24        0.983757    VIC     0.0
# 28633  +2*21+10*25        0.993867    HPG     0.0
#
# [28634 rows x 4 columns]
