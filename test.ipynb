# %%
from complete_method_new import CompleteMethod_new
import pandas as pd

vis = CompleteMethod_new(pd.read_csv("Data_VietNam_File3.csv"), "Data_CT", 63, "harmean")

# %%
vis.generate_formula(1.08, 5000, 1000000000)

# %%
vis.save_history()
