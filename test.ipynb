# %%
from complete_method import CompleteMethod
import numpy as np
import pandas as pd
import os

vis = CompleteMethod(pd.read_csv('data_quy.csv'), "Data_CT", 63)

# %%
vis.generate_formula(-1.0, 200000, 1000000, numerator_condition=False)

# %%
vis.convert_npy_file_to_DataFrame('Data_CT\high_profit_3_05_12_2022_00_00_52.npy')
