# %%
from complete_method import CompleteMethod
import numpy as np
import pandas as pd
import os

data = pd.read_csv('data.csv')
pathSaveFormula = "Data_CT/"
if not os.path.exists(pathSaveFormula):
    os.mkdir(pathSaveFormula)

vis = CompleteMethod(data, pathSaveFormula)

# %%
vis.generate_formula(target_profit=-1.0, formula_file_size=2000000, target_num_formula=30000000)

# %%
vis.save_history()
