# %%
from base import Method
import pandas as pd

vis = Method(pd.read_csv("Data_VietNam_File3.csv"), "Data/", 43)
# Out:
# Cảnh báo: Các cột không được coi là biến để sinh công thức: ['TIME', 'PROFIT', 'SYMBOL', 'EXCHANGE']. Nếu danh sách trên có một cột cần được coi là biến, hãy kiểm tra lại kiểu dữ liệu của cột.

# %%
data = vis.ham_nay_cua_chi_Trang(pd.read_csv("Quy_71.csv")[["formula"]])
data
# Out:
#            formula  geomean_profit  Value_limit  Geo_limit  Time_invest  \
# 0          -48/4-8        1.154549    -1.100048   1.158603           71
# 1         -48/4-26        1.152304    -1.177052   1.156350           71
# 2         -48/4-40        1.173993    -1.107694   1.173993           71
# 3       +4*48*59/0        1.157420     0.003324   1.157420           71
# 4      +6*64*65/33        1.159811     0.000547   1.172985           71
# ..             ...             ...          ...        ...          ...
# 799  +1*57*74/3+58        1.153248     0.333862   1.153248           71
# 800  +1*58*70/3+55        1.150460     0.371306   1.150460           71
# 801  +1*58*70/3+57        1.150460     0.371301   1.150460           71
# 802  +1*58*74/3+55        1.150913     0.372062   1.150913           71
# 803  +1*58*74/3+57        1.153248     0.372057   1.153248           71
#
#      Value_invest Com_invest  Profit_invest
# 0       -0.193903        NTC       1.241429
# ...
