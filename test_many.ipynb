# %%
from complete_method_many import CompleteMethod_many
import numpy as np
import pandas as pd
import os

vis = CompleteMethod_many(pd.read_csv("Data_VietNam_File3.csv"), "Data_many/", 63, 21)
# Out:
# Cảnh báo: Các cột không được coi là biến để sinh công thức: ['TIME', 'PROFIT', 'SYMBOL', 'EXCHANGE']. Nếu danh sách trên có một cột cần được coi là biến, hãy kiểm tra lại kiểu dữ liệu của cột.

# %%
vis.generate_formula(-1.0, 200000, 1000000)
# Out:
# Khi ngắt bằng tay thì cần tự chạy phương thức <CompleteMethod_object>.save_history() để lưu lịch sử.
# Đang chạy sinh công thức có số toán hạng là  1 . . .
# Đã lưu lịch sử.
# Đã lưu công thức
# Đang chạy sinh công thức có số toán hạng là  2 . . .
# Đã lưu lịch sử.
# Đã lưu công thức
# Đang chạy sinh công thức có số toán hạng là  3 . . .
# Đã lưu lịch sử.
# Đã lưu công thức
# Đã lưu lịch sử.
# Đã lưu công thức
# Đã lưu lịch sử.
# Đã lưu công thức
# Đã lưu lịch sử.
# Đã lưu công thức
# Đã lưu lịch sử.
# Đã lưu công thức
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 vis.generate_formula(-1.0, 200000, 1000000)
#
# File c:\Users\nguye\OneDrive\Máy tính\VIS_SinhCongThuc\complete_method_many.py:166, in CompleteMethod_many.generate_formula(self, target_profit, formula_file_size, target_num_formula, numerator_condition)
# ...

# %%
vis.save_history()
# Out:
# Đã lưu lịch sử.
# False
