# %%
from complete_method_new import CompleteMethod_new
import numpy as np
import pandas as pd
import os

vis = CompleteMethod_new(pd.read_csv("Data_VietNam_File3.csv"), "Data_new/", 63, 21)
# Out:
# Cảnh báo: Các cột không được coi là biến để sinh công thức: ['TIME', 'PROFIT', 'SYMBOL', 'EXCHANGE']. Nếu danh sách trên có một cột cần được coi là biến, hãy kiểm tra lại kiểu dữ liệu của cột.

# %%
vis.generate_formula(-1.0, 200000, 1000000)
# Out:
# Khi ngắt bằng tay thì cần tự chạy phương thức <CompleteMethod_object>.save_history() để lưu lịch sử.
# Đang chạy sinh công thức có số toán hạng là  1 . . .
# Số phần tử trong 1 cụm 1
# Đã lưu lịch sử.
# Đã lưu công thức
# Đang chạy sinh công thức có số toán hạng là  2 . . .
# Số phần tử trong 1 cụm 1
# Số phần tử trong 1 cụm 2
# Đã lưu lịch sử.
# Đã lưu công thức
# Đang chạy sinh công thức có số toán hạng là  3 . . .
# Số phần tử trong 1 cụm 1
# Đã lưu lịch sử.
# Đã lưu công thức
# Đã lưu lịch sử.
# Đã lưu công thức
# Số phần tử trong 1 cụm 3
# Đã lưu lịch sử.
# Đã lưu công thức
# Đã lưu lịch sử.
# Đã lưu công thức
# Đã lưu lịch sử.
# Đã lưu công thức
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 vis.generate_formula(-1.0, 200000, 1000000)
#
# ...

# %%
vis.save_history()
# Out:
# Đã lưu lịch sử.
# False
